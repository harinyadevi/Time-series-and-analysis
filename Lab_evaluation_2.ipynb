# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Series A.csv")

# %%
df
# Out:
#      -1
# 0     1
# 1     0
# 2    -2
# 3     1
# 4     0
# ..   ..
# 494  -2
# 495   1
# 496  -2
# 497   2
# 498  -2
#
# [499 rows x 1 columns]

# %%
#Summary statistics
df.describe()
# Out:
#                -1
# count  499.000000
# mean    -0.172345
# std      2.014595
# min     -3.000000
# 25%     -2.000000
# 50%      0.000000
# 75%      2.000000
# max      3.000000

# %%
#line plot
df.plot.line(figsize=(20, 10))

# %%
#histogram plot
df.plot.hist(figsize=(20, 10))

# %%
#acf plot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df)

# %% [markdown]
# Question 5 - Inference from the plots? What type of time series is it?
#
# Type of time series - Cyclical
#
# From the plots, we can infer that the data keeps incresing and decreasing, probably due to different external factors. Hence it follows a cyclical pattern.
#
# From the ACF plot, we can see that after 2 lags, the value again increase - which means the underlying process would be MA(2)

# %%
wt = pd.read_csv("/content/Weight.csv")

# %%
wt
# Out:
#            Date  Weights
# 0    01-01-1959      113
# 1    02-01-1959      128
# 2    03-01-1959      108
# 3    04-01-1959      136
# 4    05-01-1959      138
# ..          ...      ...
# 360  27-12-1959       98
# 361  28-12-1959      127
# 362  29-12-1959      129
# 363  30-12-1959      131
# 364  31-12-1959      132
#
# [365 rows x 2 columns]

# %%
#moving average for smoothing

from matplotlib import pyplot

rolling = wt.rolling(window=3)
rolling_mean = rolling.mean()
print(rolling_mean.head(10))
# Out:
#       Weights
# 0         NaN
# 1         NaN
# 2  116.333333
# 3  124.000000
# 4  127.333333
# 5  135.333333
# 6  130.000000
# 7  131.666667
# 8  134.333333
# 9  142.333333

# %%
# plot original and transformed dataset
wt.plot()
rolling_mean.plot(color='red')
pyplot.show()

# %%
import seaborn as sns
sns.lineplot( x = 'Date', y = 'Weights', data = wt, label = 'OriginalDataset')
  
# plot of transformed data
sns.lineplot( x = 'Date', y = 'Weights', data = rolling_mean, label = 'RollingMeanTransformedData')
